# %% [markdown]
# # FPSB vs. SPSB

# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
import seaborn as sns 

plt.rcParams.update({"text.usetex": False, 'font.size':14})
np.random.seed(1337)
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %%
R = 100_000 
n = 2 

def bstar(v, n): 
    #Fill in

# %%
for n in [2,3,5,10]: 
    print(f'\n--- n = {n} ---')
    np.random.seed(1337)
    v = np.random.uniform(0,1,(R,n))

    b_fpsb = #Fill in
    p_fpsb = #Fill in

    p_spsb = #Fill in

    print(f'Mean SPSB = {p_spsb.mean():.5f}, FPSB = {p_fpsb.mean():.5f}')

    plt.hist(p_fpsb, bins=100, density=True, alpha=0.5, label=f'FPSB mean: {p_fpsb.mean():.3f}');
    plt.hist(p_spsb, bins=100, density=True, alpha=0.5, label=f'SPSB mean: {p_spsb.mean():.3f}');
    plt.legend(); plt.title(f'${n=}$ bidders'); plt.xlabel('Payment'); 
    plt.savefig(f'img/fpsb_spsb_n{n}.pdf');
    plt.show();
# Out:
# --- n = 2 ---
# Mean SPSB = 0.33295, FPSB = 0.33426
# --- n = 3 ---
# Mean SPSB = 0.50069, FPSB = 0.50059
# --- n = 5 ---
# Mean SPSB = 0.66710, FPSB = 0.66676
# --- n = 10 ---
# Mean SPSB = 0.81850, FPSB = 0.81832
